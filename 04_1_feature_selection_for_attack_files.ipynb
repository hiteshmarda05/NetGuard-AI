# %%
##  "attacks" folder (with attack csv files) is required for the operation of the program.
##  "attacks" folder must be located in the same directory as the program.


##  the purpose of this code is to determine which features to use in the machine learning phase.
##  for this purpose, the importance weights of the attacks are calculated.
##  this calculation was made using sklearn-RandomForestRegressor.

##  the some codes parts used for calculation and graphing are taken from the following site.
##  http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html

import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor
import sklearn as sk
import time
seconds = time.time()

def folder(f_name): #this function creates a folder named "feaure_pics" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")


# CSV files names:
csv_files=os.listdir("attacks")# It creates a list of file names in the "attacks" folder.

# Headers of column
main_labels=["Flow Duration","Total Fwd Packets",   "Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets","Fwd Packet Length Max","Fwd Packet Length Min",
   "Fwd Packet Length Mean","Fwd Packet Length Std","Bwd Packet Length Max","Bwd Packet Length Min","Bwd Packet Length Mean","Bwd Packet Length Std",
   "Flow Bytes/s","Flow Packets/s","Flow IAT Mean","Flow IAT Std","Flow IAT Max","Flow IAT Min","Fwd IAT Total","Fwd IAT Mean","Fwd IAT Std","Fwd IAT Max",
   "Fwd IAT Min","Bwd IAT Total","Bwd IAT Mean","Bwd IAT Std","Bwd IAT Max","Bwd IAT Min","Fwd PSH Flags","Bwd PSH Flags","Fwd URG Flags","Bwd URG Flags",
   "Fwd Header Length","Bwd Header Length","Fwd Packets/s","Bwd Packets/s","Min Packet Length","Max Packet Length","Packet Length Mean","Packet Length Std",
   "Packet Length Variance","FIN Flag Count","SYN Flag Count","RST Flag Count","PSH Flag Count","ACK Flag Count","URG Flag Count","CWE Flag Count",
   "ECE Flag Count","Down/Up Ratio","Average Packet Size","Avg Fwd Segment Size","Avg Bwd Segment Size","Fwd Avg Bytes/Bulk",
   "Fwd Avg Packets/Bulk","Fwd Avg Bulk Rate","Bwd Avg Bytes/Bulk","Bwd Avg Packets/Bulk","Bwd Avg Bulk Rate","Subflow Fwd Packets","Subflow Fwd Bytes",
   "Subflow Bwd Packets","Subflow Bwd Bytes","Init_Win_bytes_forward","Init_Win_bytes_backward","act_data_pkt_fwd",
   "min_seg_size_forward","Active Mean","Active Std","Active Max","Active Min",
    "Idle Mean","Idle Std","Idle Max", "Idle Min","Label"]

ths = open("importance_list_for_attack_files.csv", "w")
folder("./feature_pics/")
for j in csv_files:
    df=pd.read_csv("./attacks/"+j,usecols=main_labels)
    df=df.fillna(0)
    attack_or_not=[]
    for i in df["Label"]:#it changes the normal label to "1" and the attack tag to "0" for use in the machine learning algorithm
        if i =="BENIGN":
            attack_or_not.append(1)
        else:
            attack_or_not.append(0)
    df["Label"]=attack_or_not

    y = df["Label"].values
    del df["Label"]
    X = df.values

    X = np.float32(X)
    X[np.isnan(X)] = 0
    X[np.isinf(X)] = 0


    #computing the feature importances
    forest = ExtraTreesClassifier(n_estimators=100, random_state=0, n_jobs=-1)
    forest.fit(X, y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]
    refclasscol=list(df.columns.values)
    impor_bars = pd.DataFrame({'Features':refclasscol[0:20],'importance':importances[0:20]})
    impor_bars = impor_bars.sort_values('importance',ascending=False).set_index('Features')
    plt.rcParams['figure.figsize'] = (10, 5)
    impor_bars.plot.bar();
    #printing the feature importances
    count=0
    fea_ture=j[0:-4]+"=["
    for i in impor_bars.index:
        fea_ture=fea_ture+"\""+str(i)+"\","
        count+=1
        if count==5:
            fea_ture=fea_ture[0:-1]+"]"
            break
    print(j[0:-4],"importance list:")
    print(j[0:-4],"\n",impor_bars.head(20),"\n\n\n")
    print(fea_ture)
    plt.title(j[0:-4]+" Attack - Feature Importance")
    plt.ylabel('Importance')
    plt.savefig("./feature_pics/"+j[0:-4]+".pdf", bbox_inches='tight', format='pdf')
    ths.write((  fea_ture ) )
    plt.tight_layout()
    plt.show()
    print("-----------------------------------------------------------------------------------------------\n\n\n\n")


print("mission accomplished!")
print("Total operation time: = ",time.time()- seconds ,"seconds")
ths.close()
# Out:
# Heartbleed importance list:
# Heartbleed
#                               importance
# Features
# Total Fwd Packets              0.086299
# Bwd Packet Length Max          0.069069
# Bwd Packet Length Mean         0.055028
# Bwd Packet Length Std          0.049069
# Total Backward Packets         0.043916
# Total Length of Bwd Packets    0.038766
# Flow Duration                  0.023134
# Fwd IAT Total                  0.012239
# Fwd Packet Length Max          0.011911
# Total Length of Fwd Packets    0.008863
# Flow IAT Std                   0.005033
# Fwd Packet Length Min          0.002963
# Flow Bytes/s                   0.002165
# Fwd Packet Length Mean         0.001173
# Flow Packets/s                 0.001173
# Fwd Packet Length Std          0.000000
# Bwd Packet Length Min          0.000000
# Flow IAT Mean                  0.000000
# Flow IAT Max                   0.000000
# Flow IAT Min                   0.000000
#
#
#
# Heartbleed=["Total Fwd Packets","Bwd Packet Length Max","Bwd Packet Length Mean","Bwd Packet Length Std","Total Backward Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# PortScan importance list:
# PortScan
#                               importance
# Features
# Bwd Packet Length Min          0.096640
# Bwd Packet Length Mean         0.033197
# Fwd Packet Length Min          0.029711
# Bwd Packet Length Max          0.022171
# Fwd Packet Length Mean         0.020785
# Bwd Packet Length Std          0.009751
# Fwd IAT Total                  0.009691
# Flow Duration                  0.008005
# Total Fwd Packets              0.007848
# Fwd Packet Length Max          0.007400
# Flow IAT Max                   0.007080
# Flow IAT Std                   0.006803
# Total Backward Packets         0.005932
# Total Length of Bwd Packets    0.005544
# Total Length of Fwd Packets    0.005228
# Flow IAT Mean                  0.003053
# Flow Packets/s                 0.001873
# Fwd Packet Length Std          0.000936
# Flow IAT Min                   0.000623
# Flow Bytes/s                   0.000515
#
#
#
# PortScan=["Bwd Packet Length Min","Bwd Packet Length Mean","Fwd Packet Length Min","Bwd Packet Length Max","Fwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# FTP-Patator importance list:
# FTP-Patator
#                               importance
# Features
# Bwd Packet Length Mean         0.023133
# Flow IAT Max                   0.019898
# Flow Duration                  0.018122
# Bwd Packet Length Max          0.014161
# Bwd Packet Length Min          0.013250
# Fwd IAT Total                  0.012763
# Bwd Packet Length Std          0.011198
# Total Backward Packets         0.011191
# Fwd Packet Length Mean         0.010902
# Flow IAT Std                   0.010106
# Fwd Packet Length Max          0.009690
# Fwd Packet Length Std          0.009629
# Total Length of Bwd Packets    0.009407
# Total Length of Fwd Packets    0.008677
# Flow IAT Mean                  0.005820
# Total Fwd Packets              0.004649
# Fwd Packet Length Min          0.004583
# Flow Bytes/s                   0.003613
# Flow Packets/s                 0.003101
# Flow IAT Min                   0.000666
#
#
#
# FTP-Patator=["Bwd Packet Length Mean","Flow IAT Max","Flow Duration","Bwd Packet Length Max","Bwd Packet Length Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# SSH-Patator importance list:
# SSH-Patator
#                               importance
# Features
# Bwd Packet Length Min          0.027717
# Bwd Packet Length Max          0.024984
# Flow Duration                  0.023747
# Fwd IAT Total                  0.022228
# Total Fwd Packets              0.018694
# Total Backward Packets         0.014206
# Fwd Packet Length Max          0.013776
# Bwd Packet Length Mean         0.012599
# Bwd Packet Length Std          0.012204
# Flow IAT Mean                  0.011303
# Flow IAT Max                   0.009815
# Fwd Packet Length Mean         0.009641
# Fwd Packet Length Std          0.009120
# Flow IAT Min                   0.007241
# Total Length of Bwd Packets    0.006952
# Flow Packets/s                 0.006767
# Fwd Packet Length Min          0.005244
# Flow IAT Std                   0.004772
# Total Length of Fwd Packets    0.002868
# Flow Bytes/s                   0.000671
#
#
#
# SSH-Patator=["Bwd Packet Length Min","Bwd Packet Length Max","Flow Duration","Fwd IAT Total","Total Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Infiltration importance list:
# Infiltration
#                               importance
# Features
# Fwd IAT Total                  0.081342
# Flow Duration                  0.059744
# Flow IAT Max                   0.037105
# Fwd Packet Length Max          0.025196
# Fwd Packet Length Mean         0.023773
# Total Backward Packets         0.022781
# Flow IAT Std                   0.021713
# Fwd Packet Length Std          0.018519
# Flow IAT Mean                  0.011736
# Total Length of Fwd Packets    0.011080
# Bwd Packet Length Min          0.010183
# Bwd Packet Length Max          0.009479
# Flow Bytes/s                   0.009171
# Total Fwd Packets              0.009159
# Flow IAT Min                   0.007178
# Bwd Packet Length Std          0.006010
# Total Length of Bwd Packets    0.005226
# Bwd Packet Length Mean         0.004887
# Flow Packets/s                 0.004780
# Fwd Packet Length Min          0.004566
#
#
#
# Infiltration=["Fwd IAT Total","Flow Duration","Flow IAT Max","Fwd Packet Length Max","Fwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Bot importance list:
# Bot
#                               importance
# Features
# Bwd Packet Length Mean         0.051012
# Bwd Packet Length Min          0.048422
# Bwd Packet Length Max          0.028601
# Bwd Packet Length Std          0.017428
# Total Fwd Packets              0.017100
# Fwd Packet Length Min          0.015021
# Total Backward Packets         0.015014
# Fwd IAT Total                  0.014416
# Flow IAT Max                   0.012015
# Flow Duration                  0.011576
# Total Length of Bwd Packets    0.011252
# Fwd Packet Length Max          0.009879
# Flow IAT Mean                  0.008227
# Total Length of Fwd Packets    0.007223
# Fwd Packet Length Std          0.007028
# Flow IAT Std                   0.006929
# Fwd Packet Length Mean         0.006713
# Flow Packets/s                 0.006107
# Flow Bytes/s                   0.004312
# Flow IAT Min                   0.004223
#
#
#
# Bot=["Bwd Packet Length Mean","Bwd Packet Length Min","Bwd Packet Length Max","Bwd Packet Length Std","Total Fwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS GoldenEye importance list:
# DoS GoldenEye
#                               importance
# Features
# Flow IAT Mean                  0.048741
# Bwd Packet Length Max          0.045474
# Bwd Packet Length Std          0.043819
# Flow Duration                  0.037742
# Bwd Packet Length Mean         0.032861
# Flow IAT Min                   0.030613
# Flow IAT Max                   0.026368
# Fwd IAT Total                  0.022579
# Flow IAT Std                   0.013781
# Fwd Packet Length Max          0.006216
# Bwd Packet Length Min          0.004556
# Total Backward Packets         0.004543
# Fwd Packet Length Min          0.004459
# Total Fwd Packets              0.003947
# Fwd Packet Length Mean         0.003096
# Total Length of Bwd Packets    0.002945
# Flow Packets/s                 0.002505
# Fwd Packet Length Std          0.002440
# Flow Bytes/s                   0.001366
# Total Length of Fwd Packets    0.001294
#
#
#
# DoS GoldenEye=["Flow IAT Mean","Bwd Packet Length Max","Bwd Packet Length Std","Flow Duration","Bwd Packet Length Mean"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# Web Attack importance list:
# Web Attack
#                               importance
# Features
# Flow Duration                       0.0
# Total Fwd Packets                   0.0
# Total Backward Packets              0.0
# Total Length of Fwd Packets         0.0
# Total Length of Bwd Packets         0.0
# Fwd Packet Length Max               0.0
# Fwd Packet Length Min               0.0
# Fwd Packet Length Mean              0.0
# Fwd Packet Length Std               0.0
# Bwd Packet Length Max               0.0
# Bwd Packet Length Min               0.0
# Bwd Packet Length Mean              0.0
# Bwd Packet Length Std               0.0
# Flow Bytes/s                        0.0
# Flow Packets/s                      0.0
# Flow IAT Mean                       0.0
# Flow IAT Std                        0.0
# Flow IAT Max                        0.0
# Flow IAT Min                        0.0
# Fwd IAT Total                       0.0
#
#
#
# Web Attack=["Flow Duration","Total Fwd Packets","Total Backward Packets","Total Length of Fwd Packets","Total Length of Bwd Packets"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS slowloris importance list:
# DoS slowloris
#                               importance
# Features
# Fwd IAT Total                  0.030865
# Flow Duration                  0.027380
# Flow IAT Mean                  0.027026
# Flow IAT Max                   0.026582
# Flow IAT Min                   0.023874
# Bwd Packet Length Mean         0.020510
# Flow IAT Std                   0.019495
# Bwd Packet Length Max          0.017212
# Bwd Packet Length Min          0.013873
# Bwd Packet Length Std          0.011923
# Fwd Packet Length Min          0.009096
# Fwd Packet Length Max          0.007795
# Fwd Packet Length Mean         0.007500
# Total Backward Packets         0.007399
# Total Fwd Packets              0.005618
# Fwd Packet Length Std          0.003557
# Total Length of Bwd Packets    0.003460
# Total Length of Fwd Packets    0.003135
# Flow Packets/s                 0.003021
# Flow Bytes/s                   0.001149
#
#
#
# DoS slowloris=["Fwd IAT Total","Flow Duration","Flow IAT Mean","Flow IAT Max","Flow IAT Min"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DDoS importance list:
# DDoS
#                               importance
# Features
# Bwd Packet Length Max          0.061667
# Bwd Packet Length Mean         0.039173
# Bwd Packet Length Std          0.035815
# Fwd IAT Total                  0.033242
# Flow Duration                  0.029984
# Flow IAT Std                   0.023513
# Flow IAT Max                   0.019899
# Flow IAT Mean                  0.015002
# Bwd Packet Length Min          0.008944
# Fwd Packet Length Max          0.008612
# Total Length of Fwd Packets    0.008444
# Fwd Packet Length Mean         0.008291
# Total Fwd Packets              0.008164
# Flow IAT Min                   0.006129
# Flow Bytes/s                   0.004847
# Fwd Packet Length Min          0.004663
# Flow Packets/s                 0.004403
# Total Backward Packets         0.003032
# Fwd Packet Length Std          0.002854
# Total Length of Bwd Packets    0.001699
#
#
#
# DDoS=["Bwd Packet Length Max","Bwd Packet Length Mean","Bwd Packet Length Std","Fwd IAT Total","Flow Duration"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# DoS Slowhttptest importance list:
# DoS Slowhttptest
#                               importance
# Features
# Fwd IAT Total                  0.070801
# Flow IAT Mean                  0.064388
# Flow IAT Max                   0.048071
# Flow Duration                  0.035653
# Flow IAT Std                   0.025751
# Fwd Packet Length Min          0.023716
# Bwd Packet Length Max          0.018160
# Bwd Packet Length Mean         0.015212
# Fwd Packet Length Mean         0.014101
# Bwd Packet Length Std          0.012714
# Flow IAT Min                   0.010447
# Total Length of Bwd Packets    0.006715
# Bwd Packet Length Min          0.005167
# Fwd Packet Length Max          0.004960
# Total Length of Fwd Packets    0.004051
# Flow Bytes/s                   0.003686
# Total Fwd Packets              0.003620
# Total Backward Packets         0.002423
# Flow Packets/s                 0.002385
# Fwd Packet Length Std          0.002349
#
#
#
# DoS Slowhttptest=["Fwd IAT Total","Flow IAT Mean","Flow IAT Max","Flow Duration","Flow IAT Std"]
# -----------------------------------------------------------------------------------------------
#
#
#
#
# mission accomplished!
# Total operation time: =  17.37490940093994 seconds
